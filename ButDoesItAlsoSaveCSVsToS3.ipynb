# %%
#GDP, HEALTH EXPENDITURE (AS A % OF GDP), and EASE OF DOING BUSINESS (AS A %)

import os

os.environ['AWS_ACCESS_KEY_ID'] = 'AKIAZLOYMTVZRD4DZU5O'
os.environ['AWS_SECRET_ACCESS_KEY'] = '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'

# !pip install wbgapi
# !pip install pandas
# !pip install boto3

import wbgapi as wb
import pandas as pd
import boto3
from io import StringIO

#Fetching our data:

def fetch_data(indicator, start_year, end_year):
    data = wb.data.DataFrame(indicator, time=range(start_year, end_year + 1), labels=True)
    data = data.reset_index()
    data.columns = ['Country Code', 'Country Name'] + [str(y) for y in range(start_year, end_year + 1)]
    data.set_index(['Country Code', 'Country Name'], inplace=True)
    return data

# Setting our indicators and time range:
indicators = {
    'NY.GDP.MKTP.CD': 'Gross Domestic Product (GDP) in current US dollars',
    'SH.XPD.CHEX.GD.ZS': 'Health expenditure (% of GDP)',
    'IC.BUS.EASE.XQ': 'Ease of doing business (score)'
}
start_year = 2020
end_year = 2021

s3_bucket = 'wbapibucket2'
s3 = boto3.client('s3')

#Fetching our data:
for indicator, description in indicators.items():
    print(f"\n{description}:\n")
    data = fetch_data(indicator, start_year, end_year)
    print(data)
    output_filename = f"{description.replace(' ', '_')}_data_{start_year}-{end_year}.csv"
    
    # Saving our data to the S3 bucket:
    csv_buffer = StringIO()
    data.to_csv(csv_buffer)
    s3.put_object(Bucket=s3_bucket, Key=output_filename, Body=csv_buffer.getvalue())
# Out:
# ...
#
# Gross Domestic Product (GDP) in current US dollars:
#
#                                                      2020          2021
# Country Code Country Name
# ZWE          Zimbabwe                        2.150970e+10  2.837124e+10
# ZMB          Zambia                          1.811063e+10  2.214763e+10
# YEM          Yemen, Rep.                              NaN           NaN
# PSE          West Bank and Gaza              1.553170e+10  1.803680e+10
# VIR          Virgin Islands (U.S.)           4.204000e+09           NaN
# ...                                                   ...           ...
# CEB          Central Europe and the Baltics  1.664903e+12  1.901935e+12
# CSS          Caribbean small states          6.589681e+10  7.529530e+10
# ARB          Arab World                      2.491175e+12  2.862987e+12
# AFW          Africa Western and Central      7.847997e+11  8.401873e+11
# AFE          Africa Eastern and Southern     9.341791e+11  1.089454e+12
#
# ...

# %%
#INTERNET USERS (AS A % OF POPULATION)

# !pip install boto3

import os
import wbgapi as wb
import pandas as pd
import boto3
from io import StringIO

def fetch_data(indicator, start_year, end_year):
    data = wb.data.DataFrame(indicator, time=range(start_year, end_year + 1), labels=True)
    data = data.reset_index()
    data.columns = ['Country Code', 'Country Name'] + [str(y) for y in range(start_year, end_year + 1)]
    data.set_index(['Country Code', 'Country Name'], inplace=True)
    return data

def save_data_to_s3(data, output_filename):
    s3 = boto3.client('s3')
    csv_buffer = StringIO()
    data.to_csv(csv_buffer)
    s3.put_object(Bucket='wbapibucket2', Key=output_filename, Body=csv_buffer.getvalue())

def print_and_save_data(indicator, description, start_year, end_year):
    data = fetch_data(indicator, start_year, end_year)
    print(f"{description} ({indicator}):")
    print(data)
    
    output_filename = f"{description.replace(' ', '_')}_data_{start_year}-{end_year}.csv"
    save_data_to_s3(data, output_filename)

# Setting our desired indicator and time range:
indicator = 'IT.NET.USER.ZS'  # Internet users (% of population)
description = "Internet users by country (as a %)"
start_year = 2015
end_year = 2021

print_and_save_data(indicator, description, start_year, end_year)
# Out:
# ...
# Internet users by country (as a %) (IT.NET.USER.ZS):
#                                                   2015       2016       2017  \
# Country Code Country Name
# ZWE          Zimbabwe                        22.742818  23.119989  24.400000
# ZMB          Zambia                           8.800000  10.300000  12.200000
# YEM          Yemen, Rep.                     24.085409  24.579208  26.718355
# PSE          West Bank and Gaza              56.700000  59.900000  63.300000
# VIR          Virgin Islands (U.S.)           54.839137  59.608316  64.377494
# ...                                                ...        ...        ...
# CEB          Central Europe and the Baltics  67.342967  71.342854  73.410638
# CSS          Caribbean small states          50.297503  52.607731  57.962942
# ARB          Arab World                      41.548292  43.209846  48.880204
# AFW          Africa Western and Central      18.179203  21.829266  25.176342
# ...

# %%
#BUSINESS EXTENT OF DISCLOSURE (AS A %):

import os
import wbgapi as wb
import pandas as pd
import boto3
from io import StringIO

def fetch_data(indicator, start_year, end_year):
    data = wb.data.DataFrame(indicator, time=range(start_year, end_year + 1), labels=True)
    data = data.reset_index()
    data.columns = ['Country Code', 'Country Name'] + [str(y) for y in range(start_year, end_year + 1)]
    data.set_index(['Country Code', 'Country Name'], inplace=True)
    return data

def save_data_to_s3(data, output_filename):
    s3 = boto3.client('s3')
    csv_buffer = StringIO()
    data.to_csv(csv_buffer)
    s3.put_object(Bucket='wbapibucket2', Key=output_filename, Body=csv_buffer.getvalue())

def print_and_save_data(indicator, description, start_year, end_year):
    data = fetch_data(indicator, start_year, end_year)
    print(f"{description} ({indicator}):")
    print(data)
    
    output_filename = f"{description.replace(' ', '_')}_data_{start_year}-{end_year}.csv"
    save_data_to_s3(data, output_filename)

# Setting our desired indicator and time range:
indicator = 'IC.BUS.DFRN.XQ'  # Business extent of disclosure index (%)
description = "Business extent of disclosure index (%)"
start_year = 2015
end_year = 2021

print_and_save_data(indicator, description, start_year, end_year)
# Out:
# Business extent of disclosure index (%) (IC.BUS.DFRN.XQ):
#                                                   2015       2016       2017  \
# Country Code Country Name
# ZWE          Zimbabwe                        47.803550  47.794350  48.589860
# ZMB          Zambia                          60.450460  60.254340  64.233110
# YEM          Yemen, Rep.                     38.431800  31.208330  31.266770
# PSE          West Bank and Gaza              54.174140  55.483720  59.276380
# VIR          Virgin Islands (U.S.)                 NaN        NaN        NaN
# ...                                                ...        ...        ...
# CEB          Central Europe and the Baltics  75.350967  75.728357  76.113189
# CSS          Caribbean small states          57.355512  57.754792  58.040654
# ARB          Arab World                      52.228580  52.594848  53.544242
# AFW          Africa Western and Central      45.241602  46.039510  47.234600
# ...

# %%
#FOREIGN DIRECT INVESTMENT (AS A % OF GDP)

import os
import wbgapi as wb
import pandas as pd
import boto3
from io import StringIO

#Fetching our data:
def fetch_data(indicator, start_year, end_year):
    data = wb.data.DataFrame(indicator, time=range(start_year, end_year + 1), labels=True)
    data = data.reset_index()
    data.columns = ['Country Code', 'Country Name'] + [str(y) for y in range(start_year, end_year + 1)]
    data.set_index(['Country Code', 'Country Name'], inplace=True)
    return data

def save_data_to_s3(data, output_filename):
    s3 = boto3.client('s3')
    csv_buffer = StringIO()
    data.to_csv(csv_buffer)
    s3.put_object(Bucket='wbapibucket2', Key=output_filename, Body=csv_buffer.getvalue())

def print_and_save_data(indicator, description, start_year, end_year):
    data = fetch_data(indicator, start_year, end_year)
    print(f"{description} ({indicator}):")
    print(data)
    
    output_filename = f"{description.replace(' ', '_')}_data_{start_year}-{end_year}.csv"
    save_data_to_s3(data, output_filename)

# Setting our desired indicator and time range:
indicator = 'BX.KLT.DINV.WD.GD.ZS'  # Foreign direct investment, net inflows (% of GDP)
description = "Foreign direct investment, net inflows (as % of GDP)"
start_year = 2015
end_year = 2021

print_and_save_data(indicator, description, start_year, end_year)
# Out:
# Foreign direct investment, net inflows (as % of GDP) (BX.KLT.DINV.WD.GD.ZS):
#                                                  2015      2016      2017  \
# Country Code Country Name
# ZWE          Zimbabwe                        1.999687  1.669274  1.746885
# ZMB          Zambia                          7.447417  3.162520  4.280501
# YEM          Yemen, Rep.                    -0.036388 -1.791312 -1.005319
# PSE          West Bank and Gaza              0.751036  1.924478  1.140567
# VIR          Virgin Islands (U.S.)                NaN       NaN       NaN
# ...                                               ...       ...       ...
# CEB          Central Europe and the Baltics  1.778328  8.741126  2.000977
# CSS          Caribbean small states          3.870682  4.056250  2.584916
# ARB          Arab World                      1.011216  1.301271  1.167211
# AFW          Africa Western and Central      2.039639  2.018266  2.583177
# ...

# %%
#MOBILE CELLULAR SUBSCRIPTIONS (PER 100 PEOPLE)

import os
import wbgapi as wb
import pandas as pd
import boto3
from io import StringIO

#Fetching our data:
def fetch_data(indicator, start_year, end_year):
    data = wb.data.DataFrame(indicator, time=range(start_year, end_year + 1), labels=True)
    data = data.reset_index()
    data.columns = ['Country Code', 'Country Name'] + [str(y) for y in range(start_year, end_year + 1)]
    data.set_index(['Country Code', 'Country Name'], inplace=True)
    return data

def save_data_to_s3(data, output_filename):
    s3 = boto3.client('s3')
    csv_buffer = StringIO()
    data.to_csv(csv_buffer)
    s3.put_object(Bucket='wbapibucket2', Key=output_filename, Body=csv_buffer.getvalue())

def print_and_save_data(indicator, description, start_year, end_year):
    data = fetch_data(indicator, start_year, end_year)
    print(f"{description} ({indicator}):")
    print(data)
    
    output_filename = f"{description.replace(' ', '_')}_data_{start_year}-{end_year}.csv"
    save_data_to_s3(data, output_filename)

# Setting our desired indicator and time range:
indicator = 'IT.CEL.SETS.P2'  # Mobile cellular subscriptions (per 100 people)
description = "Mobile cellular subscriptions (per 100 people)"
start_year = 2015
end_year = 2021

print_and_save_data(indicator, description, start_year, end_year)
# Out:
# Mobile cellular subscriptions (per 100 people) (IT.CEL.SETS.P2):
#                                                    2015        2016  \
# Country Code Country Name
# ZWE          Zimbabwe                         90.126929   89.110840
# ZMB          Zambia                           71.132209   71.667493
# YEM          Yemen, Rep.                      52.678026   56.135321
# PSE          West Bank and Gaza               77.961373   80.100672
# VIR          Virgin Islands (U.S.)                  NaN         NaN
# ...                                                 ...         ...
# CEB          Central Europe and the Baltics  126.076138  124.997371
# CSS          Caribbean small states          112.929408  116.765952
# ARB          Arab World                      102.997439  100.424979
# AFW          Africa Western and Central       85.200563   84.839168
# AFE          Africa Eastern and Southern      67.293873   64.284955
#
# ...

# %%
#SECURE INTERNET SERVER (PER 1 MILLION PEOPLE):

import os
import wbgapi as wb
import pandas as pd
import boto3
from io import StringIO

#Making our request/fetching our data:
def fetch_data(indicator, start_year, end_year):
    data = wb.data.DataFrame(indicator, time=range(start_year, end_year + 1), labels=True)
    data = data.reset_index()
    data.columns = ['Country Code', 'Country Name'] + [str(y) for y in range(start_year, end_year + 1)]
    data.set_index(['Country Code', 'Country Name'], inplace=True)
    return data

def save_data_to_s3(data, output_filename):
    s3 = boto3.client('s3')
    csv_buffer = StringIO()
    data.to_csv(csv_buffer)
    s3.put_object(Bucket='wbapibucket2', Key=output_filename, Body=csv_buffer.getvalue())

def print_and_save_data(indicator, description, start_year, end_year):
    data = fetch_data(indicator, start_year, end_year)
    print(f"{description} ({indicator}):")
    print(data)
    
    output_filename = f"{description.replace(' ', '_')}_data_{start_year}-{end_year}.csv"
    save_data_to_s3(data, output_filename)

# Setting our desired indicator and time range:
indicator = 'IT.NET.SECR'  # Secure internet servers (per 1 million people)
description = "Secure internet servers (per 1 million people)"
start_year = 2015
end_year = 2021

print_and_save_data(indicator, description, start_year, end_year)
# Out:
# Secure internet servers (per 1 million people) (IT.NET.SECR):
#                                               2015   2016    2017    2018  \
# Country Code Country Name
# ZWE          Zimbabwe                        162.0  194.0   435.0   673.0
# ZMB          Zambia                           90.0  145.0   714.0   715.0
# YEM          Yemen, Rep.                      37.0   39.0    94.0   107.0
# PSE          West Bank and Gaza              139.0  472.0  2440.0  2143.0
# VIR          Virgin Islands (U.S.)            57.0   90.0   113.0    92.0
# ...                                            ...    ...     ...     ...
# CEB          Central Europe and the Baltics    NaN    NaN     NaN     NaN
# CSS          Caribbean small states            NaN    NaN     NaN     NaN
# ARB          Arab World                        NaN    NaN     NaN     NaN
# AFW          Africa Western and Central        NaN    NaN     NaN     NaN
# ...
